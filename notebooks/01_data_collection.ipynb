# %%
import pandas as pd
import requests

# %%
df = pd.read_csv("/Users/macbookpro/Desktop/UAE_job_dashboard/data/raw/gsearch_jobs.csv")
print("Rows and columns:", df.shape)
print("\nColumn names:")
print(df.columns.tolist())
df.head()
# Out:
# Rows and columns: (61953, 27)
#
# Column names:
# ['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via', 'description', 'extensions', 'job_id', 'thumbnail', 'posted_at', 'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time', 'search_location', 'commute_time', 'salary_pay', 'salary_rate', 'salary_avg', 'salary_min', 'salary_max', 'salary_hourly', 'salary_yearly', 'salary_standardized', 'description_tokens']
#    Unnamed: 0  index                                             title  \
# 0           0      0                                      Data Analyst
# 1           1      1                                      Data Analyst
# 2           2      2                         Aeronautical Data Analyst
# 3           3      3  Data Analyst - Consumer Goods - Contract to Hire
# 4           4      4               Data Analyst | Workforce Management
#
#                  company_name            location           via  \
# ...

# %%
print("Top 10 job titles:")
print(df['title'].value_counts().head(10))

print("\nTop 10 locations:")
print(df['location'].value_counts().head(10))

print("\nTop 10 companies:")
print(df['company_name'].value_counts().head(10))
# Out:
# Top 10 job titles:
# title
# Data Analyst                     6444
# Senior Data Analyst              1748
# Data Scientist                    931
# Data Analyst II                   644
# Business Data Analyst             495
# Lead Data Analyst                 428
# Survey Data Analyst               422
# Data Engineer                     375
# Business Intelligence Analyst     343
# Data Analyst III                  284
# Name: count, dtype: int64
#
# Top 10 locations:
# location
#  Anywhere                  18067
#   United States            10011
# Anywhere                    9915
# United States               5547
# Denver, CO                  1062
#   Oklahoma City, OK         1028
#   Kansas City, MO            840
# Kansas City, MO              573
#   Jefferson City, MO         550
# Colorado Springs, CO         512
# Name: count, dtype: int64
#
# Top 10 companies:
# company_name
# Upwork                7533
# Talentify.io          2118
# Walmart               1829
# ...

# %%
# This column has all the skills mentioned in each job
print("Sample skills from first 5 jobs:")
print(df['description_tokens'].head())

print("\nHow many jobs have salary info?")
print(df['salary_standardized'].notna().sum())

print("\nSchedule types:")
print(df['schedule_type'].value_counts())
# Out:
# Sample skills from first 5 jobs:
# 0             ['tableau', 'r', 'python', 'sql']
# 1                                            []
# 2                                       ['sql']
# 3           ['powerpoint', 'excel', 'power_bi']
# 4    ['powerpoint', 'excel', 'outlook', 'word']
# Name: description_tokens, dtype: object
#
# How many jobs have salary info?
# 10088
#
# Schedule types:
# schedule_type
# Full-time                               45082
# Contractor                               9284
# Contractor and Temp work                 3130
# Full-time and Part-time                  1187
# Part-time                                1144
# Internship                                516
# Full-time and Contractor                  349
# Full-time and Temp work                   283
# Full-time and Internship                  192
# Temp work                                 169
# Full-time, Part-time, and Internship       92
# Full-time, Contractor, and Temp work       85
# ...

# %%
# Save to raw folder — this is your original untouched data
df.to_csv("../data/raw/gsearch_jobs.csv", index=False)
print("Raw data saved!")
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")
print("Step 1 complete!")
# Out:
# Raw data saved!
# Total rows: 61953
# Total columns: 27
# Step 1 complete!
